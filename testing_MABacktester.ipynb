# %%
import pandas as pd
import numpy as np
import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas_datareader.data as web
import datetime as dt
from MABacktester import MABacktester as MA
from OBVBacktester import OBVBacktester as OBV

pio.templates.default = 'presentation'

# %%
tester = MA("BTC-USD", 10, 30, "2015-01-01", "2018-12-31")

# %%
tester
# Out:
# MABacktester(symbol = BTC-USD, MA_S = 10, MA_L = 30, start = 2015-01-01, end = 2018-12-31)

# %%
tester.data
# Out:
#                   Close   returns         MA_S         MA_L
# Date
# 2015-01-02   286.769674       NaN          NaN          NaN
# 2015-01-05   274.473999 -0.043823          NaN          NaN
# 2015-01-06   286.188995  0.041796          NaN          NaN
# 2015-01-07   294.337006  0.028073          NaN          NaN
# 2015-01-08   283.348999 -0.038046          NaN          NaN
# ...                 ...       ...          ...          ...
# 2018-12-24  4078.599121  0.027012  3664.006136  4312.892966
# 2018-12-26  3857.297607 -0.055787  3707.277083  4228.068327
# 2018-12-27  3654.833496 -0.053916  3724.065413  4137.520443
# 2018-12-28  3870.093343  0.057228  3779.707023  4054.540546
# 2018-12-31  3742.700439 -0.033471  3829.574211  3988.018891
#
# [1006 rows x 4 columns]

# %%
tester.test_strategy()
# Out:
# (22.257599, 6.825332)

# %%
tester.results
# Out:
#                   Close   returns         MA_S         MA_L  position  \
# Date
# 2015-02-17   243.610001  0.004467   226.274168   238.273533        -1
# 2015-02-18   236.326004 -0.030356   227.179968   237.001933        -1
# 2015-02-19   240.283005  0.016605   228.522969   235.471733        -1
# 2015-02-20   241.430003  0.004762   230.954870   233.708167        -1
# 2015-02-23   238.891998 -0.010568   232.396336   232.226267         1
# ...                 ...       ...          ...          ...       ...
# 2018-12-24  4078.599121  0.027012  3664.006136  4312.892966        -1
# 2018-12-26  3857.297607 -0.055787  3707.277083  4228.068327        -1
# 2018-12-27  3654.833496 -0.053916  3724.065413  4137.520443        -1
# 2018-12-28  3870.093343  0.057228  3779.707023  4054.540546        -1
# 2018-12-31  3742.700439 -0.033471  3829.574211  3988.018891        -1
#
#             strategy   creturns  cstrategy
# Date
# 2015-02-17 -0.004467   1.004477   0.995543
# 2015-02-18  0.030356   0.974442   1.026228
# 2015-02-19 -0.016605   0.990758   1.009328
# 2015-02-20 -0.004762   0.995488   1.004533
# 2015-02-23  0.010568   0.985023   1.015205
# ...              ...        ...        ...
# 2018-12-24 -0.027012  16.817278  20.424544
# 2018-12-26  0.055787  15.904786  21.596344
# 2018-12-27  0.053916  15.069966  22.792701
# 2018-12-28 -0.057228  15.957546  21.524940
# 2018-12-31  0.033471  15.432267  22.257599
#
# [976 rows x 8 columns]

# %%
tester.plot_buys_and_sells()

# %%
tester.plot_results()

# %%
tester.optimize_parameters((10, 20, 1), (30, 40, 1))
# Out:
# (array([10., 32.]), 28.233237)

# %%
opti_tester = MA("BTC-USD", 10, 32, "2015-01-01", "2018-12-31")

# %%
opti_tester.test_strategy()
# Out:
# (28.233237, 12.396214)

# %%
opti_tester.results
# Out:
#                   Close   returns         MA_S         MA_L  position  \
# Date
# 2015-02-19   240.283005  0.016605   228.522969   238.275469        -1
# 2015-02-20   241.430003  0.004762   230.954870   237.242844        -1
# 2015-02-23   238.891998 -0.010568   232.396336   235.764813        -1
# 2015-02-24   238.735001 -0.000657   234.258836   234.027250         1
# 2015-02-25   237.470001 -0.005313   236.021936   232.593531         1
# ...                 ...       ...          ...          ...       ...
# 2018-12-24  4078.599121  0.027012  3664.006136  4449.082792        -1
# 2018-12-26  3857.297607 -0.055787  3707.277083  4365.556463        -1
# 2018-12-27  3654.833496 -0.053916  3724.065413  4278.091253        -1
# 2018-12-28  3870.093343  0.057228  3779.707023  4198.968020        -1
# 2018-12-31  3742.700439 -0.033471  3829.574211  4116.825221        -1
#
#             strategy   creturns  cstrategy
# Date
# 2015-02-19 -0.016605   1.016744   0.983532
# 2015-02-20 -0.004762   1.021597   0.978859
# 2015-02-23  0.010568   1.010858   0.989259
# 2015-02-24  0.000657   1.010194   0.989909
# 2015-02-25 -0.005313   1.004841   0.984664
# ...              ...        ...        ...
# 2018-12-24 -0.027012  17.258359  25.908050
# 2018-12-26  0.055787  16.321935  27.394451
# 2018-12-27  0.053916  15.465219  28.912001
# 2018-12-28 -0.057228  16.376079  27.303876
# 2018-12-31  0.033471  15.837023  28.233237
#
# [974 rows x 8 columns]

# %%
opti_tester.plot_buys_and_sells()

# %%
opti_tester.plot_results()

# %% [markdown]
# #### Forward testing with optimized params

# %%
opti_tester = MA("BTC-USD", 10, 32, "2019-01-01", dt.date.today())

# %%
opti_tester.test_strategy()
# Out:
# (10.798582, -0.220895)

# %%
opti_tester.results
# Out:
#                    Close   returns          MA_S          MA_L  position  \
# Date
# 2019-02-19   3947.094482  0.080590   3609.513761   3649.813174        -1
# 2019-02-20   3999.820557  0.013270   3662.860075   3654.909403         1
# 2019-02-21   3954.118164 -0.011492   3716.895109   3655.772006         1
# 2019-02-22   3986.160319  0.008071   3775.563973   3654.550507         1
# 2019-02-25   3882.696289 -0.026299   3796.227865   3649.920769         1
# ...                  ...       ...           ...           ...       ...
# 2022-04-06  43206.738281 -0.052946  45796.615104  42168.145101         1
# 2022-04-07  43503.847656  0.006853  45750.906510  42331.201986         1
# 2022-04-08  42425.824219 -0.025092  45471.153906  42491.491170         1
# 2022-04-11  39521.902344 -0.070902  44710.543750  42528.656576         1
# 2022-04-12  40127.183594  0.015199  43976.689063  42573.994059         1
#
#             strategy   creturns  cstrategy
# Date
# 2019-02-19 -0.080590   1.083926   0.922572
# 2019-02-20 -0.013270   1.098406   0.910410
# 2019-02-21 -0.011492   1.085855   0.900008
# 2019-02-22  0.008071   1.094654   0.907301
# 2019-02-25 -0.026299   1.066242   0.883751
# ...              ...        ...        ...
# 2022-04-06 -0.052946  11.865165  11.627317
# 2022-04-07  0.006853  11.946755  11.707272
# 2022-04-08 -0.025092  11.650715  11.417166
# 2022-04-11 -0.070902  10.853258  10.635695
# 2022-04-12  0.015199  11.019477  10.798582
#
# [795 rows x 8 columns]

# %%
opti_tester.plot_buys_and_sells()

# %%
opti_tester.plot_results()
