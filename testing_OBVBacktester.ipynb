# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import datetime as dt
import OBVBacktester as OBV

plt.style.use("seaborn")

# %%
tester = OBV.OBVBacktester("BTC-USD", "2015-01-01", "2018-12-31")

# %%
tester
# Out:
# OBVBacktester(symbol = BTC-USD, start = 2015-01-01, end = 2018-12-31)

# %%
tester.data
# Out:
#                   Close        Volume   returns           OBV       OBV_EMA
# Date
# 2015-01-02   286.769674  3.218138e+07       NaN  0.000000e+00  0.000000e+00
# 2015-01-05   274.473999  4.396280e+07 -0.043823 -4.396280e+07 -2.308047e+07
# 2015-01-06   286.188995  2.324570e+07  0.041796 -2.071710e+07 -2.221265e+07
# 2015-01-07   294.337006  2.486680e+07  0.028073  4.149700e+06 -1.460225e+07
# 2015-01-08   283.348999  1.998250e+07 -0.038046 -1.583280e+07 -1.489991e+07
# ...                 ...           ...       ...           ...           ...
# 2018-12-24  4078.599121  7.240969e+09  0.027012  5.585740e+10  4.765147e+10
# 2018-12-26  3857.297607  5.326548e+09 -0.055787  5.053085e+10  4.792569e+10
# 2018-12-27  3654.833496  5.130222e+09 -0.053916  4.540063e+10  4.768521e+10
# 2018-12-28  3870.093343  5.131263e+09  0.057228  5.053189e+10  4.795632e+10
# 2018-12-31  3742.700439  4.661841e+09 -0.033471  4.587005e+10  4.775763e+10
#
# [1006 rows x 5 columns]

# %%
tester.test_strategy()
# Out:
# (19.067457, 5.431556)

# %%
tester.results
# Out:
#                   Close        Volume   returns           OBV       OBV_EMA  \
# Date
# 2015-01-06   286.188995  2.324570e+07  0.041796 -2.071710e+07 -2.221265e+07
# 2015-01-07   294.337006  2.486680e+07  0.028073  4.149700e+06 -1.460225e+07
# 2015-01-08   283.348999  1.998250e+07 -0.038046 -1.583280e+07 -1.489991e+07
# 2015-01-09   276.954661  1.739457e+07 -0.022826 -3.322737e+07 -1.876617e+07
# 2015-01-12   267.795990  1.888030e+07 -0.033628 -5.210767e+07 -2.507022e+07
# ...                 ...           ...       ...           ...           ...
# 2018-12-24  4078.599121  7.240969e+09  0.027012  5.585740e+10  4.765147e+10
# 2018-12-26  3857.297607  5.326548e+09 -0.055787  5.053085e+10  4.792569e+10
# 2018-12-27  3654.833496  5.130222e+09 -0.053916  4.540063e+10  4.768521e+10
# 2018-12-28  3870.093343  5.131263e+09  0.057228  5.053189e+10  4.795632e+10
# 2018-12-31  3742.700439  4.661841e+09 -0.033471  4.587005e+10  4.775763e+10
#
#             position  strategy   creturns  cstrategy
# Date
# 2015-01-06         1 -0.041796   1.042682   0.959066
# 2015-01-07         1  0.028073   1.072368   0.986371
# 2015-01-08        -1 -0.038046   1.032335   0.949548
# 2015-01-09        -1  0.022826   1.009038   0.971471
# 2015-01-12        -1  0.033628   0.975670   1.004696
# ...              ...       ...        ...        ...
# 2018-12-24         1  0.027012  14.859692  23.298417
# 2018-12-26         1 -0.055787  14.053417  22.034264
# 2018-12-27        -1 -0.053916  13.315773  20.877716
# 2018-12-28         1 -0.057228  14.100036  19.716470
# 2018-12-31        -1 -0.033471  13.635902  19.067457
#
# [1004 rows x 9 columns]

# %%
tester.plot_results()
