# %%
import pandas as pd
import numpy as np
import plotly.io as pio
import plotly.express as px
import pandas_datareader.data as web
import datetime as dt
import OBVBacktester as OBV

pio.templates.default = 'presentation'

# %%
tester = OBV.OBVBacktester("TSLA", 20, "2015-01-01", "2018-12-31")

# %%
tester
# Out:
# OBVBacktester(symbol = TSLA, OBV_EMA = 20,  start = 2015-01-01, end = 2018-12-31)

# %%
tester.data
# Out:
#                 Close      Volume   returns         OBV       OBV_EMA
# Date
# 2015-01-02  43.862000  23822000.0       NaN         0.0  0.000000e+00
# 2015-01-05  42.018002  26842500.0 -0.042950 -26842500.0 -1.409231e+07
# 2015-01-06  42.256001  31309500.0  0.005648   4467000.0 -7.277444e+06
# 2015-01-07  42.189999  14842000.0 -0.001563 -10375000.0 -8.171661e+06
# 2015-01-08  42.124001  17212500.0 -0.001566 -27587500.0 -1.286819e+07
# ...               ...         ...       ...         ...           ...
# 2018-12-24  59.077999  27799500.0 -0.079305 -80940000.0 -1.567699e+07
# 2018-12-26  65.218002  40815500.0  0.098877 -40124500.0 -1.800532e+07
# 2018-12-27  63.226002  42875500.0 -0.031020 -83000000.0 -2.419529e+07
# 2018-12-28  66.774002  49695000.0  0.054598 -33305000.0 -2.506288e+07
# 2018-12-31  66.559998  31511500.0 -0.003210 -64816500.0 -2.884894e+07
#
# [1006 rows x 5 columns]

# %%
tester.test_strategy()
# Out:
# (0.639113, -0.94497)

# %%
tester.results
# Out:
#                 Close      Volume   returns         OBV       OBV_EMA  \
# Date
# 2015-01-06  42.256001  31309500.0  0.005648   4467000.0 -7.277444e+06
# 2015-01-07  42.189999  14842000.0 -0.001563 -10375000.0 -8.171661e+06
# 2015-01-08  42.124001  17212500.0 -0.001566 -27587500.0 -1.286819e+07
# 2015-01-09  41.332001  23341500.0 -0.018981 -50929000.0 -2.089728e+07
# 2015-01-12  40.442001  29751500.0 -0.021768 -80680500.0 -3.220081e+07
# ...               ...         ...       ...         ...           ...
# 2018-12-24  59.077999  27799500.0 -0.079305 -80940000.0 -1.567699e+07
# 2018-12-26  65.218002  40815500.0  0.098877 -40124500.0 -1.800532e+07
# 2018-12-27  63.226002  42875500.0 -0.031020 -83000000.0 -2.419529e+07
# 2018-12-28  66.774002  49695000.0  0.054598 -33305000.0 -2.506288e+07
# 2018-12-31  66.559998  31511500.0 -0.003210 -64816500.0 -2.884894e+07
#
#             position  strategy  creturns  cstrategy
# Date
# 2015-01-06         1 -0.005648  1.005664   0.994368
# 2015-01-07        -1 -0.001563  1.004093   0.992815
# 2015-01-08        -1  0.001566  1.002523   0.994370
# 2015-01-09        -1  0.018981  0.983674   1.013424
# 2015-01-12        -1  0.021768  0.962492   1.035726
# ...              ...       ...       ...        ...
# 2018-12-24        -1  0.079305  1.406016   0.720054
# 2018-12-26        -1 -0.098877  1.552144   0.652264
# 2018-12-27        -1  0.031020  1.504736   0.672814
# 2018-12-28        -1 -0.054598  1.589176   0.637064
# 2018-12-31        -1  0.003210  1.584083   0.639113
#
# [1004 rows x 9 columns]

# %%
tester.plot_results()

# %%
tester.set_parameters(30)

# %%
tester.test_strategy()
# Out:
# (0.47309, -1.110992)

# %%
tester.plot_results()

# %%
tester.update_and_run(OBV_EMA=40)
# Out:
# -0.356524

# %%
tester.optimize_parameters(OBV_EMA_range=(slice(10, 100, 1)))
# Out:
# (12.0, 1.422419)

# %%
opti_tester = OBV.OBVBacktester("TSLA", 12, "2015-01-01", "2018-12-31")

# %%
opti_tester.test_strategy()
# Out:
# (1.422419, -0.161664)

# %%
opti_tester.results
# Out:
#                 Close      Volume   returns         OBV       OBV_EMA  \
# Date
# 2015-01-06  42.256001  31309500.0  0.005648   4467000.0 -7.121373e+06
# 2015-01-07  42.189999  14842000.0 -0.001563 -10375000.0 -8.148416e+06
# 2015-01-08  42.124001  17212500.0 -0.001566 -27587500.0 -1.342995e+07
# 2015-01-09  41.332001  23341500.0 -0.018981 -50929000.0 -2.254419e+07
# 2015-01-12  40.442001  29751500.0 -0.021768 -80680500.0 -3.551710e+07
# ...               ...         ...       ...         ...           ...
# 2018-12-24  59.077999  27799500.0 -0.079305 -80940000.0 -1.835101e+07
# 2018-12-26  65.218002  40815500.0  0.098877 -40124500.0 -2.170078e+07
# 2018-12-27  63.226002  42875500.0 -0.031020 -83000000.0 -3.113143e+07
# 2018-12-28  66.774002  49695000.0  0.054598 -33305000.0 -3.146582e+07
# 2018-12-31  66.559998  31511500.0 -0.003210 -64816500.0 -3.659670e+07
#
#             position  strategy  creturns  cstrategy
# Date
# 2015-01-06         1 -0.005648  1.005664   0.994368
# 2015-01-07        -1 -0.001563  1.004093   0.992815
# 2015-01-08        -1  0.001566  1.002523   0.994370
# 2015-01-09        -1  0.018981  0.983674   1.013424
# 2015-01-12        -1  0.021768  0.962492   1.035726
# ...              ...       ...       ...        ...
# 2018-12-24        -1  0.079305  1.406016   1.602562
# 2018-12-26        -1 -0.098877  1.552144   1.451688
# 2018-12-27        -1  0.031020  1.504736   1.497425
# 2018-12-28        -1 -0.054598  1.589176   1.417860
# 2018-12-31        -1  0.003210  1.584083   1.422419
#
# [1004 rows x 9 columns]

# %%
opti_tester.plot_results()

# %% [markdown]
# #### Forward testing with optimized OBV_EMA

# %%
opti_tester = OBV.OBVBacktester("TSLA", 12, "2019-01-01", dt.date.today())

# %%
opti_tester.test_strategy()
# Out:
# (3.316681, -13.895998)

# %%
opti_tester.results
# Out:
#                   Close      Volume   returns           OBV       OBV_EMA  \
# Date
# 2019-01-04    63.537998  36970500.0  0.056094  2.144500e+06 -1.066443e+07
# 2019-01-07    66.991997  37756000.0  0.052935  3.990050e+07  5.296943e+06
# 2019-01-08    67.070000  35042500.0  0.001164  7.494300e+07  2.421953e+07
# 2019-01-09    67.706001  27164500.0  0.009438  1.021075e+08  4.315040e+07
# 2019-01-10    68.994003  30282000.0  0.018845  1.323895e+08  6.306380e+07
# ...                 ...         ...       ...           ...           ...
# 2022-04-04  1145.449951  27345300.0  0.054596  4.327358e+09  4.260386e+09
# 2022-04-05  1091.260010  26691700.0 -0.048465  4.300666e+09  4.266583e+09
# 2022-04-06  1045.760010  29782800.0 -0.042589  4.270883e+09  4.267244e+09
# 2022-04-07  1057.260010  26391400.0  0.010937  4.297275e+09  4.271864e+09
# 2022-04-08  1034.000000   3850651.0 -0.022246  4.293424e+09  4.275181e+09
#
#             position  strategy   creturns  cstrategy
# Date
# 2019-01-04         1 -0.056094   1.057697   0.945450
# 2019-01-07         1  0.052935   1.115195   0.996846
# 2019-01-08         1  0.001164   1.116494   0.998006
# 2019-01-09         1  0.009438   1.127081   1.007470
# 2019-01-10         1  0.018845   1.148522   1.026636
# ...              ...       ...        ...        ...
# 2022-04-04         1  0.054596  19.067951   3.674170
# 2022-04-05         1 -0.048465  18.165868   3.500349
# 2022-04-06         1 -0.042589  17.408444   3.354402
# 2022-04-07         1  0.010937  17.599881   3.391290
# 2022-04-08         1 -0.022246  17.212679   3.316681
#
# [823 rows x 9 columns]

# %%
opti_tester.plot_results()

# %% [markdown]
# #### Testing BTC

# %%
btc_test = OBV.OBVBacktester("BTC-USD", 79, "2015-01-01", dt.date.today())

# %%
btc_test.test_strategy()
# Out:
# (3061.709612, 2905.197149)

# %%
btc_test.results
# Out:
#                    Close        Volume   returns           OBV       OBV_EMA  \
# Date
# 2015-01-06    286.188995  2.324570e+07  0.041796 -2.071710e+07 -2.173239e+07
# 2015-01-07    294.337006  2.486680e+07  0.028073  4.149700e+06 -1.501411e+07
# 2015-01-08    283.348999  1.998250e+07 -0.038046 -1.583280e+07 -1.518624e+07
# 2015-01-09    276.954661  1.739457e+07 -0.022826 -3.322737e+07 -1.838657e+07
# 2015-01-12    267.795990  1.888030e+07 -0.033628 -5.210767e+07 -2.357736e+07
# ...                  ...           ...       ...           ...           ...
# 2022-04-04  46622.675781  3.249979e+10  0.009077  1.898294e+12  1.786426e+12
# 2022-04-05  45555.992188  2.964060e+10 -0.023145  1.868653e+12  1.788482e+12
# 2022-04-06  43206.738281  3.939340e+10 -0.052946  1.829260e+12  1.789501e+12
# 2022-04-07  43503.847656  2.610197e+10  0.006853  1.855362e+12  1.791148e+12
# 2022-04-08  42958.601562  2.449726e+10 -0.012612  1.830865e+12  1.792141e+12
#
#             position  strategy    creturns    cstrategy
# Date
# 2015-01-06         1 -0.041796    1.042682     0.959066
# 2015-01-07         1  0.028073    1.072368     0.986371
# 2015-01-08        -1 -0.038046    1.032335     0.949548
# 2015-01-09        -1  0.022826    1.009038     0.971471
# 2015-01-12        -1  0.033628    0.975670     1.004696
# ...              ...       ...         ...          ...
# 2022-04-04         1  0.009077  169.861903  3322.852453
# 2022-04-05         1 -0.023145  165.975620  3246.828669
# 2022-04-06         1 -0.052946  157.416507  3079.394605
# 2022-04-07         1  0.006853  158.498976  3100.569936
# 2022-04-08         1 -0.012612  156.512463  3061.709612
#
# [1829 rows x 9 columns]

# %%
btc_test.plot_results()
